# %%
import pandas as pd
import numpy as np
import os
import gc
from collections import defaultdict
from tqdm.notebook import tqdm
from IPython.display import display, Markdown

# Rule Conversion Function
# This function takes the string representation of a frozenset 
# (e.g., "frozenset({'Milk'})") and converts it back into a usable frozenset object.
def convert_frozenset_string(set_string):
    # This evaluates the string as Python code, returning the frozenset object directly.
    # It relies on the string being well-formed (which it should be, as we created it).
    return eval(set_string)


# Load the Generated Rules
rules = pd.read_csv('../outputs/association_rules.csv')

# Apply the function to the antecedent and consequent columns
rules['antecedents'] = rules['antecedents'].apply(convert_frozenset_string)
rules['consequents'] = rules['consequents'].apply(convert_frozenset_string)

print(f"Loaded {len(rules)} association rules. First antecedent type: {type(rules['antecedents'].iloc[0])}")

# Load the Instacart Test Data
data_path = '../data/'
orders = pd.read_csv(os.path.join(data_path, 'orders.csv'))
op_train = pd.read_csv(os.path.join(data_path, 'order_products_train.csv'))
products = pd.read_csv(os.path.join(data_path, 'products.csv'))
# Out:
# Loaded 953 association rules. First antecedent type: <class 'frozenset'>

# %%
# Identify all unique products contained in the generated rules
rule_products = set()
for s in rules['antecedents']:
    rule_products.update(s)
for s in rules['consequents']:
    rule_products.update(s)

# Filter the TEST TRANSACTIONS (op_train) to keep only products that are in our rules.
# This ensures the test set only contains items the model actually knows about.

# NOTE: This part requires modification of Cell 2.

# In Cell 2, before the merge with 'products', add this filter:
#op_train_filtered = op_train[op_train['product_id'].isin(products[products['product_name'].isin(rule_products)]['product_id'])]

# %%
# Prepare Test Set Transactions
test_orders = orders[orders['eval_set'] == 'train'][['order_id', 'user_id']]
test_transactions = test_orders.merge(op_train[['order_id', 'product_id']], on='order_id', how='left')
test_transactions = test_transactions.merge(products[['product_id', 'product_name']], on='product_id', how='left')

# Clean up memory
del orders, op_train, products
gc.collect()

# Create a dictionary mapping Order ID -> List of Products Bought
# IMPORTANT: Ensure the items are strings within the set.
test_ground_truth = test_transactions.groupby('order_id')['product_name'].apply(set).to_dict()

print(f"Prepared {len(test_ground_truth)} test baskets for evaluation.")
# Out:
# Prepared 131209 test baskets for evaluation.

# %%
def generate_recommendations(current_basket, rules_df, k=5):
    """Generates top K recommendations based on association rules."""
    
    # CRITICAL: Filter rules where the antecedent is a subset of the current basket.
    # The 'current_basket' is a set (from the ground truth).
    relevant_rules = rules_df[
        rules_df['antecedents'].apply(lambda x: x.issubset(current_basket))
    ].copy()
    
    relevant_rules['score'] = relevant_rules['confidence'] * relevant_rules['lift']
    
    recommendations = defaultdict(float)
    
    for _, row in relevant_rules.iterrows():
        # Consequent is a frozenset, but we assume single-item consequents
        # The item 'consequent_item' is now a string (e.g., 'Banana')
        consequent_item = list(row['consequents'])[0] 
        
        # Only recommend items NOT already in the basket (CRITICAL FILTER)
        if consequent_item not in current_basket:
            recommendations[consequent_item] = max(recommendations[consequent_item], row['score'])
            
    top_k = sorted(recommendations.items(), key=lambda item: item[1], reverse=True)[:k]
    return [item[0] for item in top_k]

# Offline Evaluation Execution

K = 5 
all_orders = list(test_ground_truth.keys())
SAMPLE_SIZE = 5000 
sample_orders = all_orders[:SAMPLE_SIZE] 

hit_count = 0
total_recommendations = 0

print(f"\n--- Starting Offline Evaluation (Precision@{K}) on {SAMPLE_SIZE} orders ---")

for order_id in tqdm(sample_orders, desc="Evaluating Test Orders"):
    ground_truth = test_ground_truth[order_id]
    
    # Ensure current_basket is a set of strings, matching the structure of rule items
    current_basket = ground_truth 
    
    recs = generate_recommendations(current_basket, rules, k=K)
    
    # Check hits (items recommended AND purchased in the same order)
    # The intersection of two sets (recs is list of strings, ground_truth is set of strings)
    hits = len(set(recs) & current_basket)
    hit_count += hits
    
    if len(recs) > 0:
        total_recommendations += len(recs)

# Calculate Precision@K
if total_recommendations > 0:
    precision_at_k = hit_count / total_recommendations
else:
    precision_at_k = 0

print(f"\n--- Offline Evaluation Results ---")
print(f"Total baskets evaluated: {len(sample_orders)}")
print(f"Precision@{K} (Accuracy): {precision_at_k:.4f}")
# Out:
# --- Starting Offline Evaluation (Precision@5) on 5000 orders ---
# Evaluating Test Orders:   0%|          | 0/5000 [00:00<?, ?it/s]
# --- Offline Evaluation Results ---
# Total baskets evaluated: 5000
# Precision@5 (Accuracy): 0.0000

# %%
print("\n-Top Business Actionable Rules (Interpretation for Merchandising)")

# Reload rules before frozenset conversion to display nicely
rules_display = pd.read_csv('../outputs/association_rules.csv')

# Filter for rules that represent strong cross-sell opportunities (high lift and strong confidence)
actionable_rules = rules_display[(rules_display['lift'] > 1.5) & (rules_display['confidence'] > 0.2)].head(5)

for i, row in actionable_rules.iterrows():
    antecedent = str(row['antecedents']).replace('frozenset(', '').replace(')', '').replace("'", "")
    consequent = str(row['consequents']).replace('frozenset(', '').replace(')', '').replace("'", "")
    
    print(f"\nRecommendation #{i+1}:")
    print(f"  Condition (Antecedent): IF Customer Buys {antecedent}")
    print(f"  Suggestion (Consequent): THEN Recommend {consequent}")
    print(f"  Confidence: {row['confidence']:.2f}, Lift: {row['lift']:.2f}")

    if len(eval(row['antecedents'])) >= 2:
        print("  -> **Business Use:** Perfect for a **Pre-built Bundle Discount** (Triplet Rule).")
    else:
        print("  -> **Business Use:** Ideal for a 'Frequently Bought Together' widget on the product page.")
# Out:
# -Top Business Actionable Rules (Interpretation for Merchandising)
#
# Recommendation #1:
#   Condition (Antecedent): IF Customer Buys {Non Fat Raspberry Yogurt}
#   Suggestion (Consequent): THEN Recommend {Icelandic Style Skyr Blueberry Non-fat Yogurt}
#   Confidence: 0.42, Lift: 63.56
#   -> **Business Use:** Ideal for a 'Frequently Bought Together' widget on the product page.
#
# Recommendation #2:
#   Condition (Antecedent): IF Customer Buys {Icelandic Style Skyr Blueberry Non-fat Yogurt}
#   Suggestion (Consequent): THEN Recommend {Non Fat Raspberry Yogurt}
#   Confidence: 0.36, Lift: 63.56
#   -> **Business Use:** Ideal for a 'Frequently Bought Together' widget on the product page.
#
# Recommendation #3:
#   Condition (Antecedent): IF Customer Buys {Vanilla Skyr Nonfat Yogurt}
#   Suggestion (Consequent): THEN Recommend {Icelandic Style Skyr Blueberry Non-fat Yogurt}
#   Confidence: 0.35, Lift: 53.38
#   -> **Business Use:** Ideal for a 'Frequently Bought Together' widget on the product page.
#
# Recommendation #4:
#   Condition (Antecedent): IF Customer Buys {Icelandic Style Skyr Blueberry Non-fat Yogurt}
#   Suggestion (Consequent): THEN Recommend {Vanilla Skyr Nonfat Yogurt}
#   Confidence: 0.35, Lift: 53.38
#   -> **Business Use:** Ideal for a 'Frequently Bought Together' widget on the product page.
#
# Recommendation #5:
#   Condition (Antecedent): IF Customer Buys {Total 2% Lowfat Greek Strained Yogurt With Blueberry}
#   Suggestion (Consequent): THEN Recommend {Total 2% with Strawberry Lowfat Greek Strained Yogurt}
#   Confidence: 0.44, Lift: 43.31
#   -> **Business Use:** Ideal for a 'Frequently Bought Together' widget on the product page.

# %%
# Manual Cross-Departmental Exploration

# We need to reload products/departments.

# Load products and auxiliary tables needed for department names
products = pd.read_csv(os.path.join(data_path, 'products.csv'))
departments = pd.read_csv(os.path.join(data_path, 'departments.csv'))
products = products.merge(departments[['department_id', 'department']], on='department_id', how='left')

# Reload the rules display DataFrame
rules = pd.read_csv('../outputs/association_rules.csv')


# Helper Function to Extract Item Name (Only works for single-item sets)
def get_item_name(frozenset_str):
    try:
        items = list(eval(frozenset_str))
        return items[0] if len(items) == 1 else None
    except:
        return None

# Apply Department Mapping to Rules
rules['Antecedent_Item'] = rules['antecedents'].apply(get_item_name)
rules['Consequent_Item'] = rules['consequents'].apply(get_item_name)

# Merge Antecedent Department
rules = rules.merge(products[['product_name', 'department']], 
                    left_on='Antecedent_Item', 
                    right_on='product_name', 
                    suffixes=('_ant', '_con'),
                    how='left')
rules.rename(columns={'department': 'Antecedent_Dept'}, inplace=True)

# Merge Consequent Department
rules = rules.merge(products[['product_name', 'department']], 
                    left_on='Consequent_Item', 
                    right_on='product_name', 
                    suffixes=('_ant', '_con'),
                    how='left')
rules.rename(columns={'department': 'Consequent_Dept'}, inplace=True)

# Find Cross-Departmental Rules and Search
cross_dept_rules = rules[
    (rules['Antecedent_Dept'] != rules['Consequent_Dept']) &
    (rules['Antecedent_Item'].notna())
].copy()

cross_dept_rules_sorted = cross_dept_rules.sort_values(['lift', 'support'], ascending=[False, True])

print("\n--- Top 10 Cross-Departmental Rules (Manual Exploration) ---")
print(cross_dept_rules_sorted[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'Antecedent_Dept', 'Consequent_Dept']].to_markdown(index=False))

# Search for "Diapers" or "Beer" Themes
print("\n--- Searching for 'Diapers' or 'Beer' Themes ---")
theme_rules = rules[
    (rules['Antecedent_Item'].str.contains('diaper|beer|wine', case=False, na=False)) |
    (rules['Consequent_Item'].str.contains('diaper|beer|wine', case=False, na=False))
].sort_values('lift', ascending=False)

if not theme_rules.empty:
    print(theme_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'Antecedent_Dept', 'Consequent_Dept']].head(5).to_markdown(index=False))
else:
    print("No strong rules found containing 'diaper', 'beer', or 'wine'.")

cross_dept_rules.to_csv('../outputs/cross_dept_association_rules.csv', index=False)
print("\nSaved final association rules to outputs/cross_dept_association_rules.csv")

# Cleanup
del products, departments
gc.collect()
# Out:
# --- Top 10 Cross-Departmental Rules (Manual Exploration) ---
# | antecedents                                                                   | consequents                                                   |    support |   confidence |    lift | Antecedent_Dept   | Consequent_Dept   |
# |:------------------------------------------------------------------------------|:--------------------------------------------------------------|-----------:|-------------:|--------:|:------------------|:------------------|
# | frozenset({'Blueberries'})                                                    | frozenset({'Raspberries'})                                    | 0.00209201 |    0.110676  | 5.47073 | frozen            | produce           |
# | frozenset({'Raspberries'})                                                    | frozenset({'Blueberries'})                                    | 0.00209201 |    0.103408  | 5.47073 | produce           | frozen            |
# | frozenset({'Organic Raspberries'})                                            | frozenset({'Organic Strawberries', 'Organic Hass Avocado'})   | 0.00275795 |    0.0587435 | 4.55667 | produce           | nan               |
# | frozenset({'Cucumber Kirby'})                                                 | frozenset({'Banana', 'Organic Avocado'})                      | 0.00249561 |    0.076558  | 4.46934 | produce           | nan               |
# | frozenset({'Organic Lemon'})                                                  | frozenset({'Organic Hass Avocado', 'Bag of Organic Bananas'}) | 0.00253597 |    0.0893471 | 4.4091  | produce           | nan               |
# | frozenset({'Organic Cucumber'})                                               | frozenset({'Organic Hass Avocado', 'Bag of Organic Bananas'}) | 0.00233417 |    0.0883964 | 4.36219 | produce           | nan               |
# | frozenset({'Organic Hass Avocado'})                                           | frozenset({'Organic Raspberries', 'Bag of Organic Bananas'})  | 0.00392167 |    0.0572748 | 4.17072 | produce           | nan               |
# | frozenset({'Limes'})                                                          | frozenset({'Banana', 'Large Lemon'})                          | 0.00238126 |    0.0528319 | 4.15448 | produce           | nan               |
# | frozenset({'Organic Raspberries'})                                            | frozenset({'Organic Hass Avocado', 'Bag of Organic Bananas'}) | 0.00392167 |    0.0835303 | 4.12206 | produce           | nan               |
# | frozenset({'Cucumber Kirby'})                                                 | frozenset({'Organic Baby Spinach', 'Banana'})                 | 0.00209537 |    0.0642798 | 4.00751 | produce           | nan               |
# | frozenset({'Organic Raspberries'})                                            | frozenset({'Organic Strawberries', 'Bag of Organic Bananas'}) | 0.00360888 |    0.076868  | 3.94112 | produce           | nan               |
# | frozenset({'Organic Avocado'})                                                | frozenset({'Organic Baby Spinach', 'Banana'})                 | 0.00353489 |    0.0607163 | 3.78534 | produce           | nan               |
# | frozenset({'Apple Honeycrisp Organic'})                                       | frozenset({'Organic Hass Avocado', 'Bag of Organic Bananas'}) | 0.00215255 |    0.0766284 | 3.78146 | produce           | nan               |
# | frozenset({'Organic Baby Carrots'})                                           | frozenset({'Original Hummus'})                                | 0.0020012  |    0.0822278 | 3.61178 | produce           | deli              |
# | frozenset({'Original Hummus'})                                                | frozenset({'Organic Baby Carrots'})                           | 0.0020012  |    0.0879007 | 3.61178 | deli              | produce           |
# | frozenset({'Organic Hass Avocado'})                                           | frozenset({'Organic Strawberries', 'Bag of Organic Bananas'}) | 0.00469861 |    0.0686217 | 3.51832 | produce           | nan               |
# | frozenset({'Organic Hass Avocado'})                                           | frozenset({'Organic Baby Spinach', 'Bag of Organic Bananas'}) | 0.0036257  |    0.0529522 | 3.30337 | produce           | nan               |
# | frozenset({'Blueberries'})                                                    | frozenset({'Strawberries'})                                   | 0.00291939 |    0.154448  | 3.14937 | frozen            | produce           |
# | frozenset({'Strawberries'})                                                   | frozenset({'Blueberries'})                                    | 0.00291939 |    0.0595295 | 3.14937 | produce           | frozen            |
# | frozenset({'Large Lemon'})                                                    | frozenset({'Banana', 'Organic Avocado'})                      | 0.00265033 |    0.0532576 | 3.1091  | produce           | nan               |
# | frozenset({'Organic Raspberries'})                                            | frozenset({'Organic Strawberries', 'Banana'})                 | 0.00240816 |    0.0512931 | 2.88891 | produce           | nan               |
# | frozenset({'Organic Roasted Turkey Breast'})                                  | frozenset({'Organic Hass Avocado'})                           | 0.00200456 |    0.197286  | 2.88129 | deli              | produce           |
# | frozenset({'Organic Zucchini'})                                               | frozenset({'Organic Hass Avocado', 'Bag of Organic Bananas'}) | 0.0020012  |    0.0579188 | 2.85818 | produce           | nan               |
# | frozenset({'Organic Whole Strawberries'})                                     | frozenset({'Organic Baby Spinach'})                           | 0.00205501 |    0.218059  | 2.84009 | frozen            | produce           |
# | frozenset({'Feta Cheese Crumbles'})                                           | frozenset({'Organic Baby Spinach'})                           | 0.00224    |    0.215953  | 2.81267 | dairy eggs        | produce           |
# | frozenset({'Organic Whole String Cheese'})                                    | frozenset({'Organic Hass Avocado'})                           | 0.0036257  |    0.18551   | 2.70932 | dairy eggs        | produce           |
# | frozenset({'Organic Hass Avocado'})                                           | frozenset({'Organic Whole String Cheese'})                    | 0.0036257  |    0.0529522 | 2.70932 | produce           | dairy eggs        |
# | frozenset({'Organic Strawberries'})                                           | frozenset({'Organic Hass Avocado', 'Bag of Organic Bananas'}) | 0.00469861 |    0.0547628 | 2.70244 | produce           | nan               |
# | frozenset({'100% Raw Coconut Water'})                                         | frozenset({'Organic Hass Avocado'})                           | 0.002203   |    0.182096  | 2.65946 | beverages         | produce           |
# | frozenset({'Organic Whole String Cheese'})                                    | frozenset({'Organic Strawberries'})                           | 0.00439254 |    0.224746  | 2.61944 | dairy eggs        | produce           |
# | frozenset({'Organic Strawberries'})                                           | frozenset({'Organic Whole String Cheese'})                    | 0.00439254 |    0.0511956 | 2.61944 | produce           | dairy eggs        |
# | frozenset({'Organic Unsweetened Almond Milk'})                                | frozenset({'Organic Baby Spinach'})                           | 0.00360888 |    0.197788  | 2.57608 | dairy eggs        | produce           |
# | frozenset({'Organic Unsweetened Almond Milk'})                                | frozenset({'Organic Hass Avocado'})                           | 0.00317501 |    0.174009  | 2.54135 | dairy eggs        | produce           |
# | frozenset({'Milk, Organic, Vitamin D'})                                       | frozenset({'Bag of Organic Bananas'})                         | 0.00202474 |    0.309194  | 2.46673 | dairy eggs        | produce           |
# | frozenset({'Boneless Skinless Chicken Breasts'})                              | frozenset({'Organic Avocado'})                                | 0.00245861 |    0.143053  | 2.45712 | meat seafood      | produce           |
# | frozenset({'Organic Reduced Fat Milk'})                                       | frozenset({'Organic Strawberries'})                           | 0.00223663 |    0.207101  | 2.41378 | dairy eggs        | produce           |
# | frozenset({'Shredded Parmesan'})                                              | frozenset({'Organic Baby Spinach'})                           | 0.00218618 |    0.184188  | 2.39895 | dairy eggs        | produce           |
# | frozenset({'Organic Whole String Cheese'})                                    | frozenset({'Organic Raspberries'})                            | 0.00219964 |    0.112545  | 2.39717 | dairy eggs        | produce           |
# | frozenset({'Organic Black Beans'})                                            | frozenset({'Organic Baby Spinach'})                           | 0.00208528 |    0.180916  | 2.35633 | canned goods      | produce           |
# | frozenset({'Mango Chunks'})                                                   | frozenset({'Banana'})                                         | 0.00203147 |    0.361677  | 2.33056 | frozen            | produce           |
# | frozenset({'Whipped Cream Cheese'})                                           | frozenset({'Organic Strawberries'})                           | 0.00210882 |    0.193938  | 2.26036 | dairy eggs        | produce           |
# | frozenset({'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese'}) | frozenset({'Organic Strawberries'})                           | 0.00209537 |    0.186807  | 2.17725 | dairy eggs        | produce           |
# | frozenset({'Grated Parmesan'})                                                | frozenset({'Organic Baby Spinach'})                           | 0.00249225 |    0.165254  | 2.15234 | dairy eggs        | produce           |
# | frozenset({'Frozen Organic Wild Blueberries'})                                | frozenset({'Bag of Organic Bananas'})                         | 0.00238798 |    0.269143  | 2.14721 | frozen            | produce           |
# | frozenset({'Boneless Skinless Chicken Breasts'})                              | frozenset({'Organic Baby Spinach'})                           | 0.00281849 |    0.163992  | 2.13591 | meat seafood      | produce           |
# | frozenset({'Original Hummus'})                                                | frozenset({'Organic Baby Spinach'})                           | 0.00369297 |    0.16221   | 2.1127  | deli              | produce           |
# | frozenset({'Large Alfresco Eggs'})                                            | frozenset({'Organic Hass Avocado'})                           | 0.00202474 |    0.14371   | 2.09883 | dairy eggs        | produce           |
# | frozenset({'No Salt Added Black Beans'})                                      | frozenset({'Banana'})                                         | 0.00300011 |    0.321441  | 2.07129 | canned goods      | produce           |
# | frozenset({'Organic Whole String Cheese'})                                    | frozenset({'Bag of Organic Bananas'})                         | 0.0050484  |    0.258303  | 2.06073 | dairy eggs        | produce           |
# | frozenset({'Icelandic Style Skyr Blueberry Non-fat Yogurt'})                  | frozenset({'Banana'})                                         | 0.00209537 |    0.315124  | 2.03059 | dairy eggs        | produce           |
# | frozenset({'Organic Whole String Cheese'})                                    | frozenset({'Organic Baby Spinach'})                           | 0.00303375 |    0.155223  | 2.02169 | dairy eggs        | produce           |
# | frozenset({'Organic Roasted Turkey Breast'})                                  | frozenset({'Bag of Organic Bananas'})                         | 0.00256624 |    0.252565  | 2.01495 | deli              | produce           |
# | frozenset({'Uncured Genoa Salami'})                                           | frozenset({'Organic Strawberries'})                           | 0.00236108 |    0.171764  | 2.00193 | deli              | produce           |
# | frozenset({'Total 2% All Natural Greek Strained Yogurt with Honey'})          | frozenset({'Banana'})                                         | 0.00243171 |    0.309901  | 1.99693 | dairy eggs        | produce           |
# | frozenset({'Organic Whole Strawberries'})                                     | frozenset({'Bag of Organic Bananas'})                         | 0.00235435 |    0.249822  | 1.99306 | frozen            | produce           |
# | frozenset({'Unsweetened Almondmilk'})                                         | frozenset({'Organic Hass Avocado'})                           | 0.00226018 |    0.135785  | 1.9831  | dairy eggs        | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Strawberries'})                           | 0.00730857 |    0.16896   | 1.96925 | dairy eggs        | produce           |
# | frozenset({'Organic Strawberries'})                                           | frozenset({'Organic Whole Milk'})                             | 0.00730857 |    0.0851823 | 1.96925 | produce           | dairy eggs        |
# | frozenset({'Original Hummus'})                                                | frozenset({'Organic Avocado'})                                | 0.00257633 |    0.113163  | 1.94372 | deli              | produce           |
# | frozenset({'Original Hummus'})                                                | frozenset({'Organic Raspberries'})                            | 0.00206174 |    0.0905599 | 1.9289  | deli              | produce           |
# | frozenset({'Organic Unsweetened Almond Milk'})                                | frozenset({'Bag of Organic Bananas'})                         | 0.00438245 |    0.240184  | 1.91618 | dairy eggs        | produce           |
# | frozenset({'Organic Reduced Fat 2% Milk'})                                    | frozenset({'Organic Strawberries'})                           | 0.0023409  |    0.164151  | 1.9132  | dairy eggs        | produce           |
# | frozenset({'Total 0% Greek Yogurt'})                                          | frozenset({'Banana'})                                         | 0.00242162 |    0.291971  | 1.88139 | dairy eggs        | produce           |
# | frozenset({'100% Raw Coconut Water'})                                         | frozenset({'Bag of Organic Bananas'})                         | 0.00282858 |    0.233806  | 1.86529 | beverages         | produce           |
# | frozenset({'Organic Large Brown Grade AA Cage Free Eggs'})                    | frozenset({'Bag of Organic Bananas'})                         | 0.00234762 |    0.2329    | 1.85806 | dairy eggs        | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Raspberries'})                            | 0.00375687 |    0.0868517 | 1.84991 | dairy eggs        | produce           |
# | frozenset({'Organic Raspberries'})                                            | frozenset({'Organic Whole Milk'})                             | 0.00375687 |    0.0800201 | 1.84991 | produce           | dairy eggs        |
# | frozenset({'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese'}) | frozenset({'Bag of Organic Bananas'})                         | 0.00259987 |    0.231784  | 1.84916 | dairy eggs        | produce           |
# | frozenset({'Blueberries'})                                                    | frozenset({'Banana'})                                         | 0.00540155 |    0.285765  | 1.8414  | frozen            | produce           |
# | frozenset({'Apple Honeycrisp Organic'})                                       | frozenset({'Organic Whole Milk'})                             | 0.00222991 |    0.0793822 | 1.83517 | produce           | dairy eggs        |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Apple Honeycrisp Organic'})                       | 0.00222991 |    0.0515512 | 1.83517 | dairy eggs        | produce           |
# | frozenset({'Organic Broccoli Florets'})                                       | frozenset({'Bag of Organic Bananas'})                         | 0.00250906 |    0.229963  | 1.83463 | frozen            | produce           |
# | frozenset({'Grated Parmesan'})                                                | frozenset({'Organic Strawberries'})                           | 0.00236108 |    0.156557  | 1.82469 | dairy eggs        | produce           |
# | frozenset({'Organic Cucumber'})                                               | frozenset({'Organic Whole Milk'})                             | 0.00208192 |    0.0788435 | 1.82271 | produce           | dairy eggs        |
# | frozenset({'Original Hummus'})                                                | frozenset({'Organic Hass Avocado'})                           | 0.00282522 |    0.124095  | 1.81237 | deli              | produce           |
# | frozenset({'Whipped Cream Cheese'})                                           | frozenset({'Banana'})                                         | 0.0030102  |    0.276833  | 1.78385 | dairy eggs        | produce           |
# | frozenset({'Vanilla Almond Breeze Almond Milk'})                              | frozenset({'Banana'})                                         | 0.00263015 |    0.276618  | 1.78246 | dairy eggs        | produce           |
# | frozenset({'Total 2% with Strawberry Lowfat Greek Strained Yogurt'})          | frozenset({'Banana'})                                         | 0.00277141 |    0.275309  | 1.77403 | dairy eggs        | produce           |
# | frozenset({'Total 0% Nonfat Greek Yogurt'})                                   | frozenset({'Banana'})                                         | 0.00231735 |    0.274393  | 1.76812 | dairy eggs        | produce           |
# | frozenset({'Organic Milk'})                                                   | frozenset({'Bag of Organic Bananas'})                         | 0.00216937 |    0.221269  | 1.76527 | dairy eggs        | produce           |
# | frozenset({'Organic Black Beans'})                                            | frozenset({'Bag of Organic Bananas'})                         | 0.00254606 |    0.220893  | 1.76227 | canned goods      | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Garlic'})                                 | 0.00266378 |    0.0615815 | 1.75614 | dairy eggs        | produce           |
# | frozenset({'Organic Garlic'})                                                 | frozenset({'Organic Whole Milk'})                             | 0.00266378 |    0.0759639 | 1.75614 | produce           | dairy eggs        |
# | frozenset({'Large Alfresco Eggs'})                                            | frozenset({'Bag of Organic Bananas'})                         | 0.00310102 |    0.2201    | 1.75595 | dairy eggs        | produce           |
# | frozenset({'100% Whole Wheat Bread'})                                         | frozenset({'Banana'})                                         | 0.00547891 |    0.270329  | 1.74194 | bakery            | produce           |
# | frozenset({'Unsweetened Almondmilk'})                                         | frozenset({'Bag of Organic Bananas'})                         | 0.00361225 |    0.217014  | 1.73132 | dairy eggs        | produce           |
# | frozenset({'Honey Nut Cheerios'})                                             | frozenset({'Banana'})                                         | 0.00252252 |    0.267953  | 1.72663 | breakfast         | produce           |
# | frozenset({'Organic Reduced Fat Milk'})                                       | frozenset({'Banana'})                                         | 0.00289249 |    0.267829  | 1.72583 | dairy eggs        | produce           |
# | frozenset({'Boneless Skinless Chicken Breasts'})                              | frozenset({'Banana'})                                         | 0.00456408 |    0.265558  | 1.71119 | meat seafood      | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Zucchini'})                               | 0.00255615 |    0.0590934 | 1.71029 | dairy eggs        | produce           |
# | frozenset({'Organic Zucchini'})                                               | frozenset({'Organic Whole Milk'})                             | 0.00255615 |    0.0739803 | 1.71029 | produce           | dairy eggs        |
# | frozenset({'Unsweetened Original Almond Breeze Almond Milk'})                 | frozenset({'Banana'})                                         | 0.00293285 |    0.265126  | 1.70841 | dairy eggs        | produce           |
# | frozenset({'Organic Unsweetened Almond Milk'})                                | frozenset({'Organic Strawberries'})                           | 0.00266714 |    0.146175  | 1.70369 | dairy eggs        | produce           |
# | frozenset({'Organic Reduced Fat 2% Milk'})                                    | frozenset({'Bag of Organic Bananas'})                         | 0.00301357 |    0.211321  | 1.68591 | dairy eggs        | produce           |
# | frozenset({'Original Hummus'})                                                | frozenset({'Organic Strawberries'})                           | 0.00328936 |    0.144482  | 1.68396 | deli              | produce           |
# | frozenset({'Original Hummus'})                                                | frozenset({'Banana'})                                         | 0.00591278 |    0.259713  | 1.67353 | deli              | produce           |
# | frozenset({'Organic Fat Free Milk'})                                          | frozenset({'Banana'})                                         | 0.00244852 |    0.258431  | 1.66527 | dairy eggs        | produce           |
# | frozenset({'Whole Milk'})                                                     | frozenset({'Banana'})                                         | 0.00320864 |    0.253118  | 1.63103 | dairy eggs        | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Baby Spinach'})                           | 0.00536792 |    0.124096  | 1.61628 | dairy eggs        | produce           |
# | frozenset({'Organic Baby Spinach'})                                           | frozenset({'Organic Whole Milk'})                             | 0.00536792 |    0.0699141 | 1.61628 | produce           | dairy eggs        |
# | frozenset({'Ground Turkey Breast'})                                           | frozenset({'Banana'})                                         | 0.00205837 |    0.25      | 1.61094 | meat seafood      | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Yellow Onion'})                           | 0.00250906 |    0.0580048 | 1.58599 | dairy eggs        | produce           |
# | frozenset({'Organic Yellow Onion'})                                           | frozenset({'Organic Whole Milk'})                             | 0.00250906 |    0.068604  | 1.58599 | produce           | dairy eggs        |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Bag of Organic Bananas'})                         | 0.00854629 |    0.197574  | 1.57623 | dairy eggs        | produce           |
# | frozenset({'Bag of Organic Bananas'})                                         | frozenset({'Organic Whole Milk'})                             | 0.00854629 |    0.0681818 | 1.57623 | produce           | dairy eggs        |
# | frozenset({'Half & Half'})                                                    | frozenset({'Banana'})                                         | 0.00559999 |    0.242888  | 1.56512 | dairy eggs        | produce           |
# | frozenset({'Lime Sparkling Water'})                                           | frozenset({'Banana'})                                         | 0.00374678 |    0.241282  | 1.55477 | beverages         | produce           |
# | frozenset({'Sharp Cheddar Cheese'})                                           | frozenset({'Banana'})                                         | 0.00242498 |    0.241137  | 1.55383 | dairy eggs        | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Avocado'})                                | 0.00386786 |    0.0894176 | 1.53587 | dairy eggs        | produce           |
# | frozenset({'Organic Avocado'})                                                | frozenset({'Organic Whole Milk'})                             | 0.00386786 |    0.0664356 | 1.53587 | produce           | dairy eggs        |
# | frozenset({'Feta Cheese Crumbles'})                                           | frozenset({'Banana'})                                         | 0.00245525 |    0.236706  | 1.52528 | dairy eggs        | produce           |
# | frozenset({'Organic Extra Firm Tofu'})                                        | frozenset({'Banana'})                                         | 0.00210546 |    0.236316  | 1.52276 | deli              | produce           |
# | frozenset({'Organic Blueberries'})                                            | frozenset({'Organic Whole Milk'})                             | 0.002166   |    0.0655938 | 1.5164  | produce           | dairy eggs        |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Blueberries'})                            | 0.002166   |    0.0500739 | 1.5164  | dairy eggs        | produce           |
# | frozenset({'Organic Whole String Cheese'})                                    | frozenset({'Banana'})                                         | 0.00458762 |    0.234727  | 1.51253 | dairy eggs        | produce           |
# | frozenset({'Uncured Genoa Salami'})                                           | frozenset({'Bag of Organic Bananas'})                         | 0.00259315 |    0.188647  | 1.50501 | deli              | produce           |
# | frozenset({'Whipped Cream Cheese'})                                           | frozenset({'Bag of Organic Bananas'})                         | 0.00204492 |    0.188061  | 1.50034 | dairy eggs        | produce           |
# | frozenset({'Organic Fuji Apple'})                                             | frozenset({'Organic Whole Milk'})                             | 0.00202474 |    0.0648567 | 1.49936 | produce           | dairy eggs        |
# | frozenset({'Cucumber Kirby'})                                                 | frozenset({'Organic Whole Milk'})                             | 0.0021021  |    0.0644862 | 1.4908  | produce           | dairy eggs        |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Organic Hass Avocado'})                           | 0.00440936 |    0.101936  | 1.48874 | dairy eggs        | produce           |
# | frozenset({'Organic Hass Avocado'})                                           | frozenset({'Organic Whole Milk'})                             | 0.00440936 |    0.0643973 | 1.48874 | produce           | dairy eggs        |
# | frozenset({'Banana'})                                                         | frozenset({'Organic Whole Milk'})                             | 0.0099589  |    0.0641729 | 1.48356 | produce           | dairy eggs        |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Banana'})                                         | 0.0099589  |    0.230231  | 1.48356 | dairy eggs        | produce           |
# | frozenset({'Pure Irish Butter'})                                              | frozenset({'Bag of Organic Bananas'})                         | 0.00212564 |    0.185664  | 1.48122 | dairy eggs        | produce           |
# | frozenset({'Organic Grade A Free Range Large Brown Eggs'})                    | frozenset({'Bag of Organic Bananas'})                         | 0.00242498 |    0.185157  | 1.47717 | dairy eggs        | produce           |
# | frozenset({'Unsalted Butter'})                                                | frozenset({'Banana'})                                         | 0.00259651 |    0.226393  | 1.45882 | dairy eggs        | produce           |
# | frozenset({'Unsweetened Almondmilk'})                                         | frozenset({'Organic Strawberries'})                           | 0.00208192 |    0.125076  | 1.45777 | dairy eggs        | produce           |
# | frozenset({'Organic Half & Half'})                                            | frozenset({'Bag of Organic Bananas'})                         | 0.00469861 |    0.181854  | 1.45082 | dairy eggs        | produce           |
# | frozenset({'Sparkling Water Grapefruit'})                                     | frozenset({'Banana'})                                         | 0.00558654 |    0.222565  | 1.43416 | beverages         | produce           |
# | frozenset({'Total Greek Strained Yogurt'})                                    | frozenset({'Banana'})                                         | 0.00203147 |    0.221003  | 1.42409 | dairy eggs        | produce           |
# | frozenset({'Organic 2% Reduced Fat Milk'})                                    | frozenset({'Banana'})                                         | 0.00205501 |    0.218761  | 1.40965 | dairy eggs        | produce           |
# | frozenset({'Shredded Parmesan'})                                              | frozenset({'Bag of Organic Bananas'})                         | 0.00208864 |    0.175971  | 1.40388 | dairy eggs        | produce           |
# | frozenset({'Grated Parmesan'})                                                | frozenset({'Bag of Organic Bananas'})                         | 0.00265369 |    0.175959  | 1.40379 | dairy eggs        | produce           |
# | frozenset({'Half & Half'})                                                    | frozenset({'Organic Strawberries'})                           | 0.00276468 |    0.119912  | 1.39759 | dairy eggs        | produce           |
# | frozenset({'Limes'})                                                          | frozenset({'Organic Whole Milk'})                             | 0.00272432 |    0.0604433 | 1.39733 | produce           | dairy eggs        |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Limes'})                                          | 0.00272432 |    0.0629811 | 1.39733 | dairy eggs        | produce           |
# | frozenset({'Spring Water'})                                                   | frozenset({'Bag of Organic Bananas'})                         | 0.00303711 |    0.172989  | 1.38009 | beverages         | produce           |
# | frozenset({'Pure Sparkling Water'})                                           | frozenset({'Banana'})                                         | 0.00207855 |    0.213324  | 1.37461 | beverages         | produce           |
# | frozenset({'Sparkling Water Grapefruit'})                                     | frozenset({'Organic Avocado'})                                | 0.00200456 |    0.0798606 | 1.37171 | beverages         | produce           |
# | frozenset({'100% Whole Wheat Bread'})                                         | frozenset({'Organic Strawberries'})                           | 0.00238126 |    0.117491  | 1.36937 | bakery            | produce           |
# | frozenset({'Sparkling Natural Mineral Water'})                                | frozenset({'Bag of Organic Bananas'})                         | 0.00251579 |    0.169192  | 1.34981 | beverages         | produce           |
# | frozenset({'Shredded Parmesan'})                                              | frozenset({'Banana'})                                         | 0.00247879 |    0.208841  | 1.34572 | dairy eggs        | produce           |
# | frozenset({'Fat Free Milk'})                                                  | frozenset({'Banana'})                                         | 0.00208528 |    0.208054  | 1.34065 | dairy eggs        | produce           |
# | frozenset({'Half & Half'})                                                    | frozenset({'Organic Hass Avocado'})                           | 0.00211555 |    0.0917578 | 1.34009 | dairy eggs        | produce           |
# | frozenset({'Half & Half'})                                                    | frozenset({'Organic Baby Spinach'})                           | 0.00235771 |    0.102261  | 1.33189 | dairy eggs        | produce           |
# | frozenset({'Sparkling Lemon Water'})                                          | frozenset({'Banana'})                                         | 0.00221645 |    0.206583  | 1.33117 | beverages         | produce           |
# | frozenset({'Organic Half & Half'})                                            | frozenset({'Organic Strawberries'})                           | 0.00292612 |    0.113252  | 1.31996 | dairy eggs        | produce           |
# | frozenset({'Organic Reduced Fat 2% Milk'})                                    | frozenset({'Banana'})                                         | 0.00290594 |    0.203774  | 1.31307 | dairy eggs        | produce           |
# | frozenset({'2% Reduced Fat Milk'})                                            | frozenset({'Banana'})                                         | 0.00260996 |    0.203568  | 1.31174 | dairy eggs        | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Large Lemon'})                                    | 0.00281849 |    0.0651582 | 1.30934 | dairy eggs        | produce           |
# | frozenset({'Large Lemon'})                                                    | frozenset({'Organic Whole Milk'})                             | 0.00281849 |    0.0566369 | 1.30934 | produce           | dairy eggs        |
# | frozenset({'Grated Parmesan'})                                                | frozenset({'Banana'})                                         | 0.00306402 |    0.203167  | 1.30916 | dairy eggs        | produce           |
# | frozenset({'Sparkling Water Grapefruit'})                                     | frozenset({'Organic Strawberries'})                           | 0.00281513 |    0.112153  | 1.30716 | beverages         | produce           |
# | frozenset({'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese'}) | frozenset({'Banana'})                                         | 0.00227027 |    0.202399  | 1.30421 | dairy eggs        | produce           |
# | frozenset({'100% Whole Wheat Bread'})                                         | frozenset({'Bag of Organic Bananas'})                         | 0.00331291 |    0.163458  | 1.30406 | bakery            | produce           |
# | frozenset({'Original Hummus'})                                                | frozenset({'Bag of Organic Bananas'})                         | 0.00371987 |    0.163392  | 1.30353 | deli              | produce           |
# | frozenset({'Uncured Genoa Salami'})                                           | frozenset({'Banana'})                                         | 0.00277813 |    0.202104  | 1.30231 | deli              | produce           |
# | frozenset({'Sparkling Water Grapefruit'})                                     | frozenset({'Organic Hass Avocado'})                           | 0.00221309 |    0.0881683 | 1.28767 | beverages         | produce           |
# | frozenset({'Sparkling Water Grapefruit'})                                     | frozenset({'Organic Baby Spinach'})                           | 0.00245525 |    0.0978159 | 1.274   | beverages         | produce           |
# | frozenset({'Organic Grade A Free Range Large Brown Eggs'})                    | frozenset({'Banana'})                                         | 0.00248216 |    0.189522  | 1.22124 | dairy eggs        | produce           |
# | frozenset({'Organic Unsweetened Almond Milk'})                                | frozenset({'Banana'})                                         | 0.00344744 |    0.18894   | 1.21749 | dairy eggs        | produce           |
# | frozenset({'Organic Whole Milk'})                                             | frozenset({'Strawberries'})                                   | 0.00251915 |    0.0582381 | 1.18754 | dairy eggs        | produce           |
# | frozenset({'Strawberries'})                                                   | frozenset({'Organic Whole Milk'})                             | 0.00251915 |    0.0513682 | 1.18754 | produce           | dairy eggs        |
# | frozenset({'Unsweetened Almondmilk'})                                         | frozenset({'Banana'})                                         | 0.00306065 |    0.183876  | 1.18485 | dairy eggs        | produce           |
# | frozenset({'Half & Half'})                                                    | frozenset({'Bag of Organic Bananas'})                         | 0.00333981 |    0.144858  | 1.15567 | dairy eggs        | produce           |
# | frozenset({'Extra Virgin Olive Oil'})                                         | frozenset({'Banana'})                                         | 0.00273105 |    0.16991   | 1.09486 | pantry            | produce           |
# | frozenset({'Extra Virgin Olive Oil'})                                         | frozenset({'Bag of Organic Bananas'})                         | 0.00216937 |    0.134965  | 1.07675 | pantry            | produce           |
# | frozenset({'Organic Half & Half'})                                            | frozenset({'Organic Baby Spinach'})                           | 0.00212228 |    0.0821401 | 1.06983 | dairy eggs        | produce           |
# | frozenset({'Sparkling Water Grapefruit'})                                     | frozenset({'Bag of Organic Bananas'})                         | 0.00336336 |    0.133994  | 1.069   | beverages         | produce           |
# | frozenset({'Organic Half & Half'})                                            | frozenset({'Banana'})                                         | 0.00413693 |    0.160115  | 1.03174 | dairy eggs        | produce           |
#
# --- Searching for 'Diapers' or 'Beer' Themes ---
# No strong rules found containing 'diaper', 'beer', or 'wine'.
#
# Saved final association rules to outputs/cross_dept_association_rules.csv
# 36
